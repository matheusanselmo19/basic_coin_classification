# %% [markdown]
# # Things to get Done: Data Augmentation, Image pre-processing, binary and softmax classification.

# %% [markdown]
# ### First Thing, Import the libraries to do the Image augmentations

# %%
from numpy import expand_dims
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import save_img
from matplotlib import pyplot

# %% [markdown]
# #### All code in the next 4cells are commented becasuse these steps are already done, so just give a quick read.

# %%
#main_path ='data7/coin_5/coin_5_real'
#count =10
#pathcount = 'data7/coin_5/coin_5_real'
#for i in range(10):
#    path = main_path + str(i+1)+'.jpg'
#    img = load_img(path)
    # convert to numpy array
#    data = img_to_array(img)
    # expand dimension to one sample
#    samples = expand_dims(data, 0)
    # create image data augmentation generator
#    datagen = ImageDataGenerator(rotation_range=90)
    # prepare iterator
#    it = datagen.flow(samples, batch_size=1)
#    for i in range(9):
       
        # generate batch of images
#        batch = it.next()
        # convert to unsigned integers for viewing
#        image = batch[0].astype('uint8')
        # plot raw pixel data
#        ie = img_to_array(image)
#        count = count + 1
#        pathcount = main_path+str(count)+'.jpg'
#        save_img(pathcount,ie)

# %%
#main_path ='data7/coin_5/new_coin_5_real'
#count =9
#pathcount = 'data7/coin_5/new_coin_5_real'
#for i in range(10):
#    path = main_path + str(i+1)+'.jpg'
#    img = load_img(path)
    # convert to numpy array
#    data = img_to_array(img)
    # expand dimension to one sample
#    samples = expand_dims(data, 0)
    # create image data augmentation generator
#    datagen = ImageDataGenerator(rotation_range=90)
    # prepare iterator
#    it = datagen.flow(samples, batch_size=1)
#    for i in range(9):
       
        # generate batch of images
#        batch = it.next()
        # convert to unsigned integers for viewing
#        image = batch[0].astype('uint8')
        # plot raw pixel data
#        ie = img_to_array(image)
#        count = count + 1
#        pathcount = main_path+str(count)+'.jpg'
#        save_img(pathcount,ie)

# %%
#ain_path ='data7/coin_5/coin_5_real'
#ount =100
#athcount = 'data7/coin_5/coin_5_real'
#Random Brightness Augmentation
#atagen = ImageDataGenerator(brightness_range=[0.1,1.5])
#for i in range(30):
#    path = main_path + str(i+1)+'.jpg'
#    img = load_img(path)
    # convert to numpy array
#    data = img_to_array(img)
    # expand dimension to one sample
#    samples = expand_dims(data, 0)
    # create image data augmentation generator
    # prepare iterator
#    it = datagen.flow(samples, batch_size=1)
#    for i in range(9):
       
        # generate batch of images
#        batch = it.next()
        # convert to unsigned integers for viewing
#        image = batch[0].astype('uint8')
        # plot raw pixel data
#        ie = img_to_array(image)
#        count = count + 1
#        pathcount = main_path+str(count)+'.jpg'
#        save_img(pathcount,ie)

# %%
#main_path ='data7/coin_100/coin_100_real'
#count =10
#pathcount = 'data7/coin_100/coin_100_real'
#for i in range(10):
#    path = main_path + str(i+1)+'.jpg'
#    img = load_img(path)
    # convert to numpy array
#    data = img_to_array(img)
    # expand dimension to one sample
#    samples = expand_dims(data, 0)
    # create image data augmentation generator
#    datagen2 = ImageDataGenerator(rotation_range=90)
    # prepare iterator
#    it2 = datagen2.flow(samples, batch_size=1)
#    for i in range(9):
       
        # generate batch of images
#        batch2 = it2.next()
        # convert to unsigned integers for viewing
#        image = batch2[0].astype('uint8')
        # plot raw pixel data
#        ie = img_to_array(image)
#        count = count + 1
#        pathcount = main_path+str(count)+'.jpg'
#        save_img(pathcount,ie)

# %%
#main_path ='data7/coin_100/coin_100_real'
#count =100
#pathcount = 'data7/coin_100/coin_100_real'
#Random Brightness Augmentation
#datagen = ImageDataGenerator(brightness_range=[0.1,1.5])
#for i in range(30):
#    path = main_path + str(i+1)+'.jpg'
#    img = load_img(path)
    # convert to numpy array
#    data = img_to_array(img)
    # expand dimension to one sample
#    samples = expand_dims(data, 0)
    # create image data augmentation generator
    # prepare iterator
#    it = datagen.flow(samples, batch_size=1)
 #   for i in range(9):
       
        # generate batch of images
#        batch = it.next()
        # convert to unsigned integers for viewing
#        image = batch[0].astype('uint8')
        # plot raw pixel data
 #       ie = img_to_array(image)
#        count = count + 1
#        pathcount = main_path+str(count)+'.jpg'
#        save_img(pathcount,ie)

# %% [markdown]
# ### It time do the data preprocessing. First, Let's import the Kera's module that do this job

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
            'data_set',
            labels="inferred",
            label_mode="binary",
            class_names=None,
            color_mode="rgb",
            batch_size=32,
            image_size=(256, 256),
            shuffle=True,
            seed=123,
            validation_split= 0.2,
            subset="training")
# Out:
# Found 839 files belonging to 2 classes.
# Using 672 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
            'data_set',
            labels="inferred",
            label_mode="binary",
            class_names=None,
            color_mode="rgb",
            batch_size=32,
            image_size=(256, 256),
            shuffle=True,
            seed=123,
            validation_split= 0.2,
            subset="validation")
# Out:
# Found 839 files belonging to 2 classes.
# Using 167 files for validation.

# %% [markdown]
# #### Let's check the names of the classes and see some images from the dataset

# %%
class_names = train_ds.class_names
print("The class names in the trainng set are:",class_names)
# Out:
# The class names in the trainng set are: ['coin_100', 'coin_5']

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Data Normalization

# %%
from tensorflow.keras import layers
import numpy as np

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
first_image = image_batch[0]
# Notice the pixels values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-0852d34d8d7c> in <module>
#       5
#       6 normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
# ----> 7 first_image = image_batch[0]
#       8 # Notice the pixels values are now in `[0,1]`.
#       9 print(np.min(first_image), np.max(first_image))
#
# NameError: name 'image_batch' is not defined

# %% [markdown]
# ### Let's put hands on the CNN, I mean, It's time to build it!!!

# %%
from tensorflow.keras.models import Sequential


num_classes = 2



model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(256, 256, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(2,2),
  layers.Conv2D(32, (3,3), padding='same', activation='relu'),
  layers.MaxPooling2D(2,2),
  layers.Conv2D(64, (3,3), padding='same', activation='relu'),
  layers.MaxPooling2D(2,2),
  #layers.Dropout(0.2),  
  layers.Conv2D(64, (3,3), padding='same', activation='relu'),
  layers.MaxPooling2D(2,2),
  layers.Flatten(),
  layers.Dense(256, activation='relu'),
  layers.Dense(2, activation ='sigmoid')
])


model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# rescaling_1 (Rescaling)      (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# ...

# %% [markdown]
# ### Train the model

# %%
epochs = 5
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 21/21 [==============================] - 19s 920ms/step - loss: 0.6732 - accuracy: 0.5729 - val_loss: 0.5894 - val_accuracy: 0.7485
# Epoch 2/5
# 21/21 [==============================] - 19s 912ms/step - loss: 0.4930 - accuracy: 0.8170 - val_loss: 0.3862 - val_accuracy: 0.9102
# Epoch 3/5
# 21/21 [==============================] - 21s 985ms/step - loss: 0.3450 - accuracy: 0.9762 - val_loss: 0.3182 - val_accuracy: 1.0000
# Epoch 4/5
# 21/21 [==============================] - 21s 994ms/step - loss: 0.3200 - accuracy: 0.9970 - val_loss: 0.3146 - val_accuracy: 1.0000
# Epoch 5/5
# 21/21 [==============================] - 21s 984ms/step - loss: 0.3178 - accuracy: 0.9955 - val_loss: 0.3141 - val_accuracy: 1.0000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# ### Check the CNN with images that are outside of trainning and validation set

# %%
img_2_check = load_img('/home/matheusans/main/IA )/small projects/only_for_test/st1.jpg',target_size=(256, 256))
img_array = img_to_array(img_2_check)
img_array = tf.expand_dims(img_array,0)
predictions = model.predict(img_array)
plt.figure()
plt.imshow(img_2_check)
print(predictions)
score = tf.nn.softmax(predictions[0])
print(score)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# [[3.5295477e-07 9.9999976e-01]]
# tf.Tensor([0.26894155 0.7310585 ], shape=(2,), dtype=float32)
# This image most likely belongs to coin_5 with a 73.11 percent confidence.
